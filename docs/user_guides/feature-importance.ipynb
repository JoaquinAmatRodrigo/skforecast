# %% [markdown]
# # Feature importance
#
# The importance of the predictors included in a forecaster can be obtained using the method `get_feature_importance`. This method accesses the `coef_` and `feature_importances_` attributes of the internal regressor.
#
# To do a proper interpretation of the feature importance, it es needed to understand how feature importance is estimated in each machine learning model. For example.................in linear models,  or in rendom forest.
#
# User should visit the documentation of the machine learning model to further investigations.

# %% [markdown]
# <script src="https://kit.fontawesome.com/d20edc211b.js" crossorigin="anonymous"></script>
#
# <div class="admonition note" name="html-admonition" style="background: rgba(255,145,0,.1); padding-top: 0px; padding-bottom: 6px; border-radius: 8px; border-left: 8px solid #ff9100;">
#
# <p class="title">
#     <i class="fa-triangle-exclamation fa" style="font-size: 18px; color:#ff9100;"></i>
#     <b> &nbsp Warning</b>
# </p>
#
# This method only returns values if the regressor used inside the forecaster has the attribute `coef_` or `feature_importances_`.
#
# </div>

# %% [markdown]
# ## Libraries

# %%
# Libraries
# ==============================================================================
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Ridge
from skforecast.ForecasterAutoreg import ForecasterAutoreg
from skforecast.ForecasterAutoregDirect import ForecasterAutoregDirect

# %% [markdown]
# ## Data

# %%
# Download data
# ==============================================================================
url = ('https://raw.githubusercontent.com/JoaquinAmatRodrigo/skforecast/master/data/h2o_exog.csv')
data = pd.read_csv(url, sep=',', header=0, names=['date', 'y', 'exog_1', 'exog_2'])

# Data preprocessing
# ==============================================================================
data['date'] = pd.to_datetime(data['date'], format='%Y/%m/%d')
data = data.set_index('date')
data = data.asfreq('MS')

# %% [markdown]
# ## Extract feature importance from trained forecaster

# %%
# Create and fit forecaster
# ==============================================================================
forecaster = ForecasterAutoreg(
                 regressor = RandomForestRegressor(random_state=123),
                 lags = 5
             )

forecaster.fit(y=data['y'], exog=data[['exog_1', 'exog_2']])

# Predictors importance
# ==============================================================================
forecaster.get_feature_importance()
# Out:
#   feature  importance
# 0   lag_1    0.530186
# 1   lag_2    0.100529
# 2   lag_3    0.023620
# 3   lag_4    0.070458
# 4   lag_5    0.063155
# 5  exog_1    0.047043
# 6  exog_2    0.165009

# %%
# Create and fit forecaster
# ==============================================================================
forecaster = ForecasterAutoreg(
                 regressor = Ridge(random_state=123),
                 lags = 5
             )

forecaster.fit(y=data['y'], exog=data[['exog_1', 'exog_2']])

forecaster.get_feature_importance()
# Out:
#   feature  importance
# 0   lag_1    0.327688
# 1   lag_2   -0.073593
# 2   lag_3   -0.152202
# 3   lag_4   -0.217106
# 4   lag_5   -0.145800
# 5  exog_1    0.379798
# 6  exog_2    0.668162

# %% [markdown]
# Since `ForecasterAutoregDirect` fits one model per step, it is necessary to specify from which model retrieves its feature importance.

# %%
# Create and fit forecaster
# ==============================================================================
forecaster = ForecasterAutoregDirect(
                 regressor = RandomForestRegressor(random_state=123),
                 steps = 10,
                 lags = 5
             )

forecaster.fit(y=data['y'], exog=data[['exog_1', 'exog_2']])

# Predictors importance
# ==============================================================================
forecaster.get_feature_importance(step=1)
# Out:
#   feature  importance
# 0   lag_1    0.530194
# 1   lag_2    0.100517
# 2   lag_3    0.026218
# 3   lag_4    0.077921
# 4   lag_5    0.050994
# 5  exog_1    0.056439
# 6  exog_2    0.157717

# %%
# %%html
# <style>
# .jupyter-wrapper .jp-CodeCell .jp-Cell-inputWrapper .jp-InputPrompt {display: none;}
# </style>
# Out:
# <style>
# .jupyter-wrapper .jp-CodeCell .jp-Cell-inputWrapper .jp-InputPrompt {display: none;}
# </style>
