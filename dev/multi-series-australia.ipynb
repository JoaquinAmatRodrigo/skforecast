# %% [markdown]
# # Single series vs multi series forecasting
#
# In univariate time series forecasting, a single time series is modeled as a linear or nonlinear combination of its lags. That is, the past values of the series are used to forecast its future. In multi-time series forecasting, two or more time series are modeled together using a single model.
#
# ¿Is it better to create a model for each series or a single one for all of them? In this document several comparisons are done in order to identify when is it recommended to apply each one of the approaches:
#
# + Individual linear models vs multi-series linear models.
# + Individual non-linear models vs multi-series non-linear models.
# + Multiple series that follow the same internal dynamics vs multiple time series with different internal dynamics.

# %% [markdown]
# ## Libraries

# %%
# Libraries
# ==============================================================================
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

from skforecast.ForecasterAutoregMultiSeries import ForecasterAutoregMultiSeries
from skforecast.ForecasterAutoreg import ForecasterAutoreg
from skforecast.model_selection import backtesting_forecaster
from skforecast.model_selection_multiseries import backtesting_forecaster_multiseries
from skforecast.model_selection_multiseries import grid_search_forecaster_multiseries
# Out:
# /home/ximo/anaconda3/envs/skforecast/lib/python3.9/site-packages/statsmodels/compat/pandas.py:61: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import Int64Index as NumericIndex

# %% [markdown]
# ## Data

# %%
# Data download
# ==============================================================================
url = ('https://raw.githubusercontent.com/JoaquinAmatRodrigo/'
       'Estadistica-machine-learning-python/master/data/victoria_tourism_by_purpose.csv')

#url = ('https://raw.githubusercontent.com/JoaquinAmatRodrigo/'
#       'Estadistica-machine-learning-python/master/data/victoria_tourism_by_region.csv')

data = pd.read_csv(url, sep=',')

# Data preparation (aggregation at daily level)
# ==============================================================================
data['date_time'] = pd.to_datetime(data['date_time'], format='%Y-%m-%d')
data = data.set_index('date_time')
data = data.asfreq('QS-OCT')
data = data.sort_index()
data
# Out:
#               Ballarat  Bendigo Loddon  Central Highlands  Central Murray  \
# date_time
# 1998-01-01  182.239341      231.685977          88.907326      196.298722
# 1998-04-01  137.566539      221.580798         105.157731      198.161741
# 1998-07-01  117.642761      128.054955          98.756975      112.972132
# 1998-10-01  136.072724      186.653927         144.406547      220.754389
# 1999-01-01  156.456242      177.441857         102.308064      210.963458
# ...                ...             ...                ...             ...
# 2016-10-01  157.294300      279.346387          96.424347      223.313411
# 2017-01-01  199.279617      247.280908         139.803003      191.457786
# 2017-04-01  209.912525      239.037901         123.597844      165.509582
# 2017-07-01  116.664987      209.227103         102.925640      120.163813
# 2017-10-01  206.100287      270.104262         137.739166      257.185211
#
#             Geelong and the Bellarine   Gippsland    Goulburn  \
# date_time
# 1998-01-01                 255.444832  382.608956  153.398516
# 1998-04-01                 191.665942  267.978316  177.725751
# 1998-07-01                 217.110171  257.236810  157.503674
# 1998-10-01                 198.470931  227.187402  148.590895
# 1999-01-01                 349.265308  322.139674   99.591407
# ...                               ...         ...         ...
# 2016-10-01                 411.781435  271.844959  142.197602
# 2017-01-01                 436.913878  494.208800  200.177205
# 2017-04-01                 298.921110  297.930150  166.948107
# 2017-07-01                 295.321654  300.691029  150.427527
# 2017-10-01                 320.019841  314.397694  184.947492
#
#             Great Ocean Road  High Country       Lakes  ...      Mallee  \
# date_time                                               ...
# 1998-01-01        739.350975    320.504578  211.835892  ...  182.084599
# 1998-04-01        357.589902    355.467743  245.945174  ...  186.326419
# 1998-07-01        342.321758    356.656700  197.998048  ...  187.347077
# 1998-10-01        441.392695    233.869672  142.120114  ...  204.834119
# 1999-01-01        604.517171    286.864136  152.450558  ...  153.666996
# ...                      ...           ...         ...  ...         ...
# 2016-10-01        497.803425    295.053884  180.174077  ...  174.838856
# 2017-01-01        746.105679    436.203586  247.788468  ...  180.901286
# 2017-04-01        469.990589    370.527061  195.403472  ...  192.050080
# 2017-07-01        456.167501    494.434526  118.215934  ...  203.486486
# 2017-10-01        513.789863    362.936705  189.575504  ...  163.576681
#
#               Melbourne  Melbourne East  Murray East   Peninsula  \
# date_time
# 1998-01-01  1578.548409       86.852958    22.317190  694.723679
# 1998-04-01  1506.071351       58.932986    30.996086  246.630629
# 1998-07-01  1522.214954       66.816989    30.265351  183.430857
# 1998-10-01  1511.182434       59.963763    32.335720  299.016342
# 1999-01-01  1449.122359       44.579431    29.145540  564.870434
# ...                 ...             ...          ...         ...
# 2016-10-01  2250.004154      196.484019    50.217918  323.612115
# 2017-01-01  2161.489065      187.248649    66.460920  561.769558
# 2017-04-01  2100.863710      175.592647    31.119323  324.780704
# 2017-07-01  2319.358716      139.007151    46.965701  278.815856
# 2017-10-01  2632.952853      151.539953    49.178366  454.859447
#
#             Phillip Island  Spa Country  Upper Yarra  Western Grampians  \
# date_time
# 1998-01-01      364.043288    86.196006   102.791022          86.996591
# 1998-04-01      166.243645    74.356890    74.855136          84.939977
# 1998-07-01       83.032823    60.778546    59.465405          79.974884
# 1998-10-01      215.677891    46.013284    35.238855         116.235617
# 1999-01-01      263.710141    65.299169    67.823457         101.765635
# ...                    ...          ...          ...                ...
# 2016-10-01      189.961263   114.619880    59.649892         102.374415
# 2017-01-01      339.895742    87.922404   114.135901          92.961571
# 2017-04-01      196.475838    56.129943    93.991505          71.596771
# 2017-07-01      156.062346   100.115699    39.804266          56.845597
# 2017-10-01      238.132877    95.348813    75.098642         119.910638
#
#               Wimmera
# date_time
# 1998-01-01  18.804743
# 1998-04-01  52.482311
# 1998-07-01  35.657551
# 1998-10-01  27.204455
# 1999-01-01  50.219851
# ...               ...
# 2016-10-01  25.709937
# 2017-01-01  62.933796
# 2017-04-01  41.844623
# 2017-07-01  62.596749
# 2017-10-01  45.150048
#
# [80 rows x 21 columns]

# %%
# Split data into train-test
# ==============================================================================
end_train = '2012-12-31 23:59:00'
data_train = data.loc[:end_train, :].copy()
data_test  = data.loc[end_train:, :].copy()

print(f"Train dates : {data_train.index.min()} --- {data_train.index.max()}  (n={len(data_train)})")
print(f"Test dates  : {data_test.index.min()} --- {data_test.index.max()}  (n={len(data_test)})")
# Out:
# Train dates : 1998-01-01 00:00:00 --- 2012-10-01 00:00:00  (n=60)
# Test dates  : 2013-01-01 00:00:00 --- 2017-10-01 00:00:00  (n=20)

# %%
# Plot time series
# ==============================================================================
fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(9, 10), sharex=True)
for i, col in enumerate(data.columns):
    data_train[col].plot(label='train', ax=axes[i])
    data_test[col].plot(label='test', ax=axes[i])
    axes[i].set_xlabel('')
    axes[i].set_ylabel('visitors')
    axes[i].set_title(col)
    axes[i].legend()
fig.tight_layout()
# Out:
# /tmp/ipykernel_26256/1304426636.py:11: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   fig.tight_layout()

# %%
# Autocorrelation plot
# ==============================================================================
fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(9, 10), sharex=True)
for i, col in enumerate(data.columns):
    plot_acf(data[col], ax=axes[i], lags=53)
    axes[i].set_title(col)
plt.show()

# %% [markdown]
# ## Multi series forecaster with linear models

# %% [markdown]
# For this first study, the forecasting performance of a multi-series forecaster (non-multivariate) will be compared with that of single forecasters. For all of them, a linear model will be used as regressor.

# %% [markdown]
# First, an individual autoregressive forecaster is trained for each series and their forecasting capability is measured with backtesting.

# %%
# ForecasterAutoreg with linear models
# ==============================================================================
forecaster = ForecasterAutoreg(
                 regressor        = LinearRegression(),
                 lags             = [1, 2, 3, 4, 53],
                 transformer_y    = StandardScaler(),
                 transformer_exog = None
             )

metric_demand, predictions_demand = backtesting_forecaster(
                                        forecaster         = forecaster,
                                        y                  = data['conventional'],
                                        initial_train_size = len(data_train),
                                        fixed_train_size   = True,
                                        steps              = 1,
                                        metric             = 'mean_absolute_error',
                                        refit              = True,
                                        verbose            = False
                                )

metric_temperature, predictions_temperature = backtesting_forecaster(
                                                    forecaster         = forecaster,
                                                    y                  = data['organic'],
                                                    initial_train_size = len(data_train),
                                                    fixed_train_size   = True,
                                                    steps              = 1,
                                                    metric             = 'mean_absolute_error',
                                                    refit              = True,
                                                    verbose            = False
                                              )

# %%
# Plot predictions
# ==============================================================================
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(9, 5), sharex=True)

data_test['conventional'].plot(label='test', ax=axes[0])
predictions_demand.plot(label='pred', ax=axes[0])
axes[0].set_xlabel('')
axes[0].set_ylabel('MW')
axes[0].set_title('Energy demand')
axes[0].legend()

data_test['organic'].plot(label='test', ax=axes[1])
predictions_temperature.plot(label='pred', ax=axes[1])
axes[1].set_xlabel('')
axes[1].set_ylabel('ºC')
axes[1].set_title('Temperature')
axes[0].legend()

fig.tight_layout()
plt.show();

# %%
# Backtesting metrics
# ==============================================================================
print('Backtesting metrics individual forecasters')
print('===================================================')
print(f"Demand: {metric_demand:.2f}")
print(f"Temperature: {metric_temperature:.2f}")
# Out:
# Backtesting metrics individual forecasters
# ===================================================
# Demand: 210179.03
# Temperature: 5230.33

# %% [markdown]
# Now, a multi-series (non-multivariate) forecaster is trained to model both series at the same time. As for the single forecasters, its performance is measured with backtesting.

# %%
# ForecasterAutoregMultiSeries with linear models
# ==============================================================================
forecaster = ForecasterAutoregMultiSeries(
                 regressor          = LinearRegression(),
                 lags               = [1, 2, 3, 4, 53],
                 transformer_series = StandardScaler()
             )

# Backtesting
# ==============================================================================
metric_demand, predictions_demand = backtesting_forecaster_multiseries(
                                          forecaster         = forecaster,
                                          series             = data[['conventional', 'organic']],
                                          level              = 'conventional',
                                          initial_train_size = len(data_train),
                                          fixed_train_size   = True,
                                          steps              = 1,
                                          metric             = 'mean_absolute_error',
                                          refit              = True,
                                          verbose            = False
                                    )

metric_temperature, predictions_temperature = backtesting_forecaster_multiseries(
                                                 forecaster         = forecaster,
                                                 series             = data[['conventional', 'organic']],
                                                 level              = 'organic',
                                                 initial_train_size = len(data_train),
                                                 fixed_train_size   = True,
                                                 steps              = 1,
                                                 metric             = 'mean_absolute_error',
                                                 refit              = True,
                                                 verbose            = False
                                              )

# %%
# Backtesting metrics
# ==============================================================================
print('Backtesting metrics using a multi-series forecaster')
print('===================================================')
print(f"Demand: {metric_demand:.2f}")
print(f"Temperature: {metric_temperature:.2f}")
# Out:
# Backtesting metrics using a multi-series forecaster
# ===================================================
# Demand: 207145.69
# Temperature: 5060.17

# %% [markdown]
# The performance of the multi-series forecaster is slightly better. In addition, it also has the advantage of maintaining only one model instead of two.

# %% [markdown]
# In the previous example, both time series had a similar dynamic: the current value is highly correlated with the lags 1, 2, 3, 4, 53. What would happen if one the series do not share the same internal dynamics?
#
# To better understand the behavior of the multi-series forecaster in this scenario, volume of sales of organic avicado is replaced with random noise, then, the forecaster is fitted and evaluated.

# %%
# Copy data and modify Temperature column as a normal distribution
# ==============================================================================
np.random.seed(123)
data_modified = data.copy()
data_modified['organic'] = np.random.normal(size=len(data_modified), loc=60_000, scale=1000)

# Split data into train-val-test
# ==============================================================================
data_train_modified = data_modified.loc[:end_train, :].copy()
data_test_modified  = data_modified.loc[end_train:, :].copy()

print(f"Train dates : {data_train_modified.index.min()} --- {data_train_modified.index.max()}  (n={len(data_train_modified)})")
print(f"Test dates  : {data_test_modified.index.min()} --- {data_test_modified.index.max()}  (n={len(data_test_modified)})")

# Plot Temperature
# ==============================================================================
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(9, 5), sharex=True)
data_train_modified['conventional'].plot(label='train', ax=axes[0])
data_test_modified['conventional'].plot(label='test', ax=axes[0])
axes[0].set_xlabel('')
axes[0].set_ylabel('MW')
axes[0].set_title('Energy demand')
axes[0].legend()

data_train_modified['organic'].plot(label='train', ax=axes[1])
data_test_modified['organic'].plot(label='test', ax=axes[1])
axes[1].set_xlabel('')
axes[1].set_ylabel('MW')
axes[1].set_title('Energy demand')
axes[1].legend()
axes[1].legend()
plt.show();
# Out:
# Train dates : 2015-01-04 00:00:00 --- 2017-09-24 00:00:00  (n=143)
# Test dates  : 2017-10-01 00:00:00 --- 2018-03-25 00:00:00  (n=26)

# %%
# Backtesting
# ==============================================================================
metric_demand, predictions_demand = backtesting_forecaster_multiseries(
                                          forecaster         = forecaster,
                                          series             = data_modified[['conventional', 'organic']],
                                          level              = 'conventional',
                                          initial_train_size = len(data_train_modified),
                                          fixed_train_size   = True,
                                          steps              = 1,
                                          metric             = 'mean_absolute_error',
                                          refit              = True,
                                          verbose            = False
                                    )

# %%
# Backtesting metrics
# ==============================================================================
print('Backtesting metrics using a multi-series forecaster')
print('===================================================')
print(f"Demand: {metric_demand:.2f}")
# Out:
# Backtesting metrics using a multi-series forecaster
# ===================================================
# Demand: 218006.68

# %% [markdown]
# The error of the model has increased remarkably. This is due two the fact that the model is constrained to learn a unique global pattern for both series. Since the time series have very different internal dynamics (relation between their current and past values) the model is no capable of learning a pattern that suits both series.

# %% [markdown]
# ## Multi series forecaster with non linear models

# %% [markdown]
# The same experiment is repeated, but this time using a non lineal model.

# %%
# ForecasterAutoreg with non linear models
# ==============================================================================
forecaster = ForecasterAutoreg(
                 regressor        = RandomForestRegressor(random_state=123, n_jobs=-1),
                 lags             = 24,
                 #transformer_y    = StandardScaler(),
                 transformer_exog = None
             )

metric_demand, predictions_demand = backtesting_forecaster(
                                        forecaster         = forecaster,
                                        y                  = data['Demand'],
                                        initial_train_size = len(data_train),
                                        fixed_train_size   = True,
                                        steps              = 24,
                                        metric             = 'mean_absolute_error',
                                        refit              = True,
                                        verbose            = False
                                )

metric_temperature, predictions_temperature = backtesting_forecaster(
                                                    forecaster         = forecaster,
                                                    y                  = data['Temperature'],
                                                    initial_train_size = len(data_train),
                                                    fixed_train_size   = True,
                                                    steps              = 24,
                                                    metric             = 'mean_absolute_error',
                                                    refit              = True,
                                                    verbose            = False
                                              )

# %%
# Backtesting metrics
# ==============================================================================
print(f"Backtest error Demand: {metric_demand:.2f}")
print(f"Backtest error Temperature: {metric_temperature:.2f}")
# Out:
# Backtest error Demand: 632.25
# Backtest error Temperature: 2.16

# %%
# ForecasterAutoregMultiSeries with non linear models
# ==============================================================================
forecaster = ForecasterAutoregMultiSeries(
                 regressor          = RandomForestRegressor(random_state=123, n_jobs=-1),
                 lags               = 24,
                 #transformer_series = StandardScaler(),
                 transformer_exog   = None
             )

# Backtesting
# ==============================================================================
metric_demand, predictions_demand = backtesting_forecaster_multiseries(
                                          forecaster         = forecaster,
                                          series             = data[['Demand', 'Temperature']],
                                          level              = 'Demand',
                                          initial_train_size = len(data_train),
                                          fixed_train_size   = True,
                                          steps              = 24,
                                          metric             = 'mean_absolute_error',
                                          refit              = True,
                                          verbose            = False
                                    )

metric_temperature, predictions_temperature = backtesting_forecaster_multiseries(
                                                 forecaster         = forecaster,
                                                 series             = data[['Demand', 'Temperature']],
                                                 level              = 'Temperature',
                                                 initial_train_size = len(data_train),
                                                 fixed_train_size   = True,
                                                 steps              = 24,
                                                 metric             = 'mean_absolute_error',
                                                 refit              = True,
                                                 verbose            = False
                                              )

# %%
# Backtesting metrics
# ==============================================================================
print(f"Backtest error Demand: {metric_demand:.2f}")
print(f"Backtest error Temperature: {metric_temperature:.2f}")
# Out:
# Backtest error Demand: 664.99
# Backtest error Temperature: 2.01

# %% [markdown]
# Again, the performance of moth approaches are very similar. Let's see what happen if the resies do not share the same dinamycs.

# %%
# ForecasterAutoregMultiSeries with linear models
# ==============================================================================
forecaster = ForecasterAutoregMultiSeries(
                 regressor          = RandomForestRegressor(random_state=123, n_jobs=-1),
                 lags               = 24,
                 transformer_series = StandardScaler(),
                 transformer_exog   = None
             )

# Backtesting
# ==============================================================================
metric_demand, predictions_demand = backtesting_forecaster_multiseries(
                                          forecaster         = forecaster,
                                          series             = data_modified[['Demand', 'Temperature']],
                                          level              = 'Demand',
                                          initial_train_size = len(data_train_modified),
                                          fixed_train_size   = True,
                                          steps              = 24,
                                          metric             = 'mean_absolute_error',
                                          refit              = True,
                                          verbose            = False
                                    )

# %%
# Backtesting metrics
# ==============================================================================
print(f"Backtest error Demand: {metric_demand:.2f}")
# Out:
# Backtest error Demand: 684.26

# %% [markdown]
# When using a non linear model, the forecasting performance is not harmed even though the time series do not follow the same dynamics. This is because the model is being able to identify that the series have more differences than similarities, and has flexibility enough to learn a different pattern for each one of the series.
#
# One way to verify this hypothesis is to analyze how the threes of the model are created.

# %%
from sklearn.tree import export_text

forecaster.fit(series=data_modified[['Demand', 'Temperature']])
feature_names = list(forecaster.create_train_X_y(data_modified[['Demand', 'Temperature']])[0].columns)

for tree in forecaster.regressor.estimators_[:3]:
    
    print(export_text(
        decision_tree = tree,
        feature_names = feature_names,
        max_depth = 2
    )
)
# Out:
# |--- lag_1 <= -0.01
# |   |--- Temperature <= 0.50
# |   |   |--- lag_24 <= -0.72
# |   |   |   |--- truncated branch of depth 17
# |   |   |--- lag_24 >  -0.72
# |   |   |   |--- truncated branch of depth 17
# |   |--- Temperature >  0.50
# |   |   |--- lag_3 <= 1.66
# |   |   |   |--- truncated branch of depth 25
# |   |   |--- lag_3 >  1.66
# |   |   |   |--- truncated branch of depth 9
# |--- lag_1 >  -0.01
# |   |--- Demand <= 0.50
# |   |   |--- lag_22 <= 1.39
# |   |   |   |--- truncated branch of depth 26
# |   |   |--- lag_22 >  1.39
# |   |   |   |--- truncated branch of depth 9
# |   |--- Demand >  0.50
# |   |   |--- lag_1 <= 0.65
# |   |   |   |--- truncated branch of depth 15
# |   |   |--- lag_1 >  0.65
# |   |   |   |--- truncated branch of depth 16
#
# |--- lag_1 <= -0.24
# |   |--- Temperature <= 0.50
# |   |   |--- lag_24 <= -0.61
# |   |   |   |--- truncated branch of depth 15
# |   |   |--- lag_24 >  -0.61
# |   |   |   |--- truncated branch of depth 16
# |   |--- Temperature >  0.50
# |   |   |--- lag_1 <= -0.25
# |   |   |   |--- truncated branch of depth 25
# |   |   |--- lag_1 >  -0.25
# |   |   |   |--- truncated branch of depth 3
# |--- lag_1 >  -0.24
# |   |--- Demand <= 0.50
# |   |   |--- lag_21 <= 2.56
# |   |   |   |--- truncated branch of depth 23
# |   |   |--- lag_21 >  2.56
# |   |   |   |--- truncated branch of depth 3
# |   |--- Demand >  0.50
# |   |   |--- lag_1 <= 0.53
# |   |   |   |--- truncated branch of depth 15
# |   |   |--- lag_1 >  0.53
# |   |   |   |--- truncated branch of depth 19
#
# |--- lag_1 <= 0.29
# |   |--- lag_24 <= -0.76
# |   |   |--- Temperature <= 0.50
# |   |   |   |--- truncated branch of depth 15
# |   |   |--- Temperature >  0.50
# |   |   |   |--- truncated branch of depth 15
# |   |--- lag_24 >  -0.76
# |   |   |--- lag_24 <= 0.18
# |   |   |   |--- truncated branch of depth 34
# |   |   |--- lag_24 >  0.18
# |   |   |   |--- truncated branch of depth 22
# |--- lag_1 >  0.29
# |   |--- Temperature <= 0.50
# |   |   |--- lag_1 <= 1.05
# |   |   |   |--- truncated branch of depth 17
# |   |   |--- lag_1 >  1.05
# |   |   |   |--- truncated branch of depth 17
# |   |--- Temperature >  0.50
# |   |   |--- lag_3 <= 2.04
# |   |   |   |--- truncated branch of depth 24
# |   |   |--- lag_3 >  2.04
# |   |   |   |--- truncated branch of depth 4

# %%
forecaster = ForecasterAutoregMultiSeries(
                 regressor          = RandomForestRegressor(random_state=123, n_jobs=-1),
                 lags               = 24,
                 transformer_exog   = None
             )


forecaster.fit(series=data_modified[['Demand', 'Temperature']])

for tree in forecaster.regressor.estimators_[:10]:
    
    print(export_text(
        decision_tree = tree,
        feature_names = feature_names,
        max_depth = 2
    )
)
# Out:
# |--- Temperature <= 0.50
# |   |--- lag_1 <= 9965.84
# |   |   |--- lag_24 <= 8731.67
# |   |   |   |--- truncated branch of depth 17
# |   |   |--- lag_24 >  8731.67
# |   |   |   |--- truncated branch of depth 17
# |   |--- lag_1 >  9965.84
# |   |   |--- lag_1 <= 10980.40
# |   |   |   |--- truncated branch of depth 14
# |   |   |--- lag_1 >  10980.40
# |   |   |   |--- truncated branch of depth 16
# |--- Temperature >  0.50
# |   |--- lag_17 <= 10.41
# |   |   |--- lag_19 <= 8.65
# |   |   |   |--- truncated branch of depth 11
# |   |   |--- lag_19 >  8.65
# |   |   |   |--- truncated branch of depth 28
# |   |--- lag_17 >  10.41
# |   |   |--- lag_3 <= 10.28
# |   |   |   |--- truncated branch of depth 18
# |   |   |--- lag_3 >  10.28
# |   |   |   |--- truncated branch of depth 19
#
# |--- Demand <= 0.50
# |   |--- lag_16 <= 10.74
# |   |   |--- lag_19 <= 11.09
# |   |   |   |--- truncated branch of depth 29
# |   |   |--- lag_19 >  11.09
# |   |   |   |--- truncated branch of depth 17
# |   |--- lag_16 >  10.74
# |   |   |--- lag_11 <= 10.99
# |   |   |   |--- truncated branch of depth 23
# |   |   |--- lag_11 >  10.99
# |   |   |   |--- truncated branch of depth 10
# |--- Demand >  0.50
# |   |--- lag_1 <= 10028.92
# |   |   |--- lag_24 <= 8855.49
# |   |   |   |--- truncated branch of depth 19
# |   |   |--- lag_24 >  8855.49
# |   |   |   |--- truncated branch of depth 19
# |   |--- lag_1 >  10028.92
# |   |   |--- lag_1 <= 11282.66
# |   |   |   |--- truncated branch of depth 17
# |   |   |--- lag_1 >  11282.66
# |   |   |   |--- truncated branch of depth 16
#
# |--- lag_5 <= 3236.52
# |   |--- lag_15 <= 12.22
# |   |   |--- lag_21 <= 12.50
# |   |   |   |--- truncated branch of depth 34
# |   |   |--- lag_21 >  12.50
# |   |   |   |--- truncated branch of depth 3
# |   |--- lag_15 >  12.22
# |   |   |--- lag_11 <= 9.68
# |   |   |   |--- truncated branch of depth 3
# |   |   |--- lag_11 >  9.68
# |   |   |   |--- truncated branch of depth 3
# |--- lag_5 >  3236.52
# |   |--- lag_1 <= 9714.65
# |   |   |--- lag_24 <= 8784.49
# |   |   |   |--- truncated branch of depth 16
# |   |   |--- lag_24 >  8784.49
# |   |   |   |--- truncated branch of depth 16
# |   |--- lag_1 >  9714.65
# |   |   |--- lag_1 <= 11270.14
# |   |   |   |--- truncated branch of depth 17
# |   |   |--- lag_1 >  11270.14
# |   |   |   |--- truncated branch of depth 16
#
# |--- lag_11 <= 3236.52
# |   |--- lag_4 <= 12.22
# |   |   |--- lag_24 <= 9.37
# |   |   |   |--- truncated branch of depth 17
# |   |   |--- lag_24 >  9.37
# |   |   |   |--- truncated branch of depth 29
# |   |--- lag_4 >  12.22
# |   |   |--- lag_24 <= 10.36
# |   |   |   |--- truncated branch of depth 4
# |   |   |--- lag_24 >  10.36
# |   |   |   |--- truncated branch of depth 3
# |--- lag_11 >  3236.52
# |   |--- lag_1 <= 9797.43
# |   |   |--- lag_24 <= 8874.05
# |   |   |   |--- truncated branch of depth 18
# |   |   |--- lag_24 >  8874.05
# |   |   |   |--- truncated branch of depth 19
# |   |--- lag_1 >  9797.43
# |   |   |--- lag_1 <= 11559.09
# |   |   |   |--- truncated branch of depth 16
# |   |   |--- lag_1 >  11559.09
# |   |   |   |--- truncated branch of depth 14
#
# |--- Temperature <= 0.50
# |   |--- lag_1 <= 9798.85
# |   |   |--- lag_24 <= 8788.75
# |   |   |   |--- truncated branch of depth 16
# |   |   |--- lag_24 >  8788.75
# |   |   |   |--- truncated branch of depth 16
# |   |--- lag_1 >  9798.85
# |   |   |--- lag_1 <= 11236.58
# |   |   |   |--- truncated branch of depth 17
# |   |   |--- lag_1 >  11236.58
# |   |   |   |--- truncated branch of depth 20
# |--- Temperature >  0.50
# |   |--- lag_1 <= 7.91
# |   |   |--- lag_5 <= 9.75
# |   |   |   |--- truncated branch of depth 4
# |   |   |--- lag_5 >  9.75
# |   |   |   |--- truncated branch of depth 5
# |   |--- lag_1 >  7.91
# |   |   |--- lag_3 <= 13.27
# |   |   |   |--- truncated branch of depth 29
# |   |   |--- lag_3 >  13.27
# |   |   |   |--- value: [7.58]
#
# |--- lag_2 <= 3236.21
# |   |--- lag_21 <= 11.27
# |   |   |--- lag_3 <= 11.13
# |   |   |   |--- truncated branch of depth 29
# |   |   |--- lag_3 >  11.13
# |   |   |   |--- truncated branch of depth 14
# |   |--- lag_21 >  11.27
# |   |   |--- lag_20 <= 8.48
# |   |   |   |--- truncated branch of depth 4
# |   |   |--- lag_20 >  8.48
# |   |   |   |--- truncated branch of depth 13
# |--- lag_2 >  3236.21
# |   |--- lag_1 <= 9764.90
# |   |   |--- lag_24 <= 8486.44
# |   |   |   |--- truncated branch of depth 15
# |   |   |--- lag_24 >  8486.44
# |   |   |   |--- truncated branch of depth 17
# |   |--- lag_1 >  9764.90
# |   |   |--- lag_1 <= 11236.58
# |   |   |   |--- truncated branch of depth 17
# |   |   |--- lag_1 >  11236.58
# |   |   |   |--- truncated branch of depth 17
#
# |--- lag_13 <= 3236.21
# |   |--- lag_17 <= 11.41
# |   |   |--- lag_18 <= 11.56
# |   |   |   |--- truncated branch of depth 23
# |   |   |--- lag_18 >  11.56
# |   |   |   |--- truncated branch of depth 12
# |   |--- lag_17 >  11.41
# |   |   |--- lag_10 <= 11.20
# |   |   |   |--- truncated branch of depth 15
# |   |   |--- lag_10 >  11.20
# |   |   |   |--- truncated branch of depth 5
# |--- lag_13 >  3236.21
# |   |--- lag_1 <= 9384.82
# |   |   |--- lag_24 <= 8669.37
# |   |   |   |--- truncated branch of depth 15
# |   |   |--- lag_24 >  8669.37
# |   |   |   |--- truncated branch of depth 13
# |   |--- lag_1 >  9384.82
# |   |   |--- lag_1 <= 11270.14
# |   |   |   |--- truncated branch of depth 18
# |   |   |--- lag_1 >  11270.14
# |   |   |   |--- truncated branch of depth 14
#
# |--- lag_10 <= 3236.52
# |   |--- lag_7 <= 11.31
# |   |   |--- lag_17 <= 8.35
# |   |   |   |--- truncated branch of depth 11
# |   |   |--- lag_17 >  8.35
# |   |   |   |--- truncated branch of depth 24
# |   |--- lag_7 >  11.31
# |   |   |--- lag_2 <= 9.73
# |   |   |   |--- truncated branch of depth 13
# |   |   |--- lag_2 >  9.73
# |   |   |   |--- truncated branch of depth 11
# |--- lag_10 >  3236.52
# |   |--- lag_1 <= 9797.43
# |   |   |--- lag_24 <= 8673.36
# |   |   |   |--- truncated branch of depth 20
# |   |   |--- lag_24 >  8673.36
# |   |   |   |--- truncated branch of depth 17
# |   |--- lag_1 >  9797.43
# |   |   |--- lag_1 <= 11297.26
# |   |   |   |--- truncated branch of depth 16
# |   |   |--- lag_1 >  11297.26
# |   |   |   |--- truncated branch of depth 17
#
# |--- Temperature <= 0.50
# |   |--- lag_1 <= 9963.52
# |   |   |--- lag_24 <= 8802.79
# |   |   |   |--- truncated branch of depth 16
# |   |   |--- lag_24 >  8802.79
# |   |   |   |--- truncated branch of depth 17
# |   |--- lag_1 >  9963.52
# |   |   |--- lag_1 <= 11270.25
# |   |   |   |--- truncated branch of depth 17
# |   |   |--- lag_1 >  11270.25
# |   |   |   |--- truncated branch of depth 16
# |--- Temperature >  0.50
# |   |--- lag_21 <= 11.23
# |   |   |--- lag_22 <= 12.26
# |   |   |   |--- truncated branch of depth 34
# |   |   |--- lag_22 >  12.26
# |   |   |   |--- truncated branch of depth 6
# |   |--- lag_21 >  11.23
# |   |   |--- lag_9 <= 10.55
# |   |   |   |--- truncated branch of depth 14
# |   |   |--- lag_9 >  10.55
# |   |   |   |--- truncated branch of depth 9
#
# |--- Temperature <= 0.50
# |   |--- lag_1 <= 9170.38
# |   |   |--- lag_24 <= 8648.16
# |   |   |   |--- truncated branch of depth 16
# |   |   |--- lag_24 >  8648.16
# |   |   |   |--- truncated branch of depth 16
# |   |--- lag_1 >  9170.38
# |   |   |--- lag_1 <= 10517.94
# |   |   |   |--- truncated branch of depth 18
# |   |   |--- lag_1 >  10517.94
# |   |   |   |--- truncated branch of depth 17
# |--- Temperature >  0.50
# |   |--- lag_9 <= 11.42
# |   |   |--- lag_9 <= 11.35
# |   |   |   |--- truncated branch of depth 27
# |   |   |--- lag_9 >  11.35
# |   |   |   |--- truncated branch of depth 6
# |   |--- lag_9 >  11.42
# |   |   |--- lag_22 <= 8.38
# |   |   |   |--- truncated branch of depth 3
# |   |   |--- lag_22 >  8.38
# |   |   |   |--- truncated branch of depth 12

# %%
print(export_text(
        decision_tree = forecaster.regressor.estimators_[0],
        feature_names = feature_names,
        max_depth = 2
    )
)
# Out:
# |--- lag_1 <= -0.01
# |   |--- Demand <= 0.50
# |   |   |--- lag_3 <= 1.66
# |   |   |   |--- truncated branch of depth 25
# |   |   |--- lag_3 >  1.66
# |   |   |   |--- truncated branch of depth 9
# |   |--- Demand >  0.50
# |   |   |--- lag_24 <= -0.72
# |   |   |   |--- truncated branch of depth 17
# |   |   |--- lag_24 >  -0.72
# |   |   |   |--- truncated branch of depth 17
# |--- lag_1 >  -0.01
# |   |--- Temperature <= 0.50
# |   |   |--- lag_1 <= 0.65
# |   |   |   |--- truncated branch of depth 15
# |   |   |--- lag_1 >  0.65
# |   |   |   |--- truncated branch of depth 16
# |   |--- Temperature >  0.50
# |   |   |--- lag_22 <= 1.39
# |   |   |   |--- truncated branch of depth 26
# |   |   |--- lag_22 >  1.39
# |   |   |   |--- truncated branch of depth 9

# %%
r = export_text(
        decision_tree = forecaster.regressor.estimators_[0],
        feature_names = feature_names
    )

re.split(r"|--- [a-zA-Z]", r)

# %%
top_3_nodes = []
feature_names = list(forecaster.create_train_X_y(data_modified[['Demand', 'Temperature']])[0].columns)

# %%
top_3_nodes = []
feature_names = list(forecaster.create_train_X_y(data_modified[['Demand', 'Temperature']])[0].columns)

for tree in forecaster.regressor.estimators_:
    r = export_text(
        decision_tree = tree,
        feature_names = feature_names
    )
    r = [re.sub('\|--- ', '', node) for node in r.split('|   |')]
    r = [re.sub('--- ', '', node) for node in r]
    r = [re.sub('  +', '', node) for node in r]
    r = [node.split(' ')[0]  for node in r]
    r = [word for word in r if word in feature_names]
    # remove duplicates
    #r = list(dict.fromkeys(r))
    top_3_nodes.append(r)

# %%
top_3_nodes[0]
# Out:
# ['lag_1',
#  'Demand',
#  'lag_3',
#  'lag_12',
#  'lag_4',
#  'lag_24',
#  'lag_24',
#  'lag_21',
#  'lag_21',
#  'lag_4',
#  'lag_9',
#  'lag_11',
#  'lag_10',
#  'lag_9',
#  'lag_9',
#  'lag_4',
#  'lag_4',
#  'lag_10',
#  'lag_19',
#  'lag_20',
#  'lag_15',
#  'lag_15',
#  'lag_20',
#  'lag_18',
#  'lag_18',
#  'lag_19',
#  'lag_18',
#  'lag_18',
#  'lag_18',
#  'lag_18',
#  'lag_11',
#  'lag_9',
#  'lag_14',
#  'lag_14',
#  'lag_7',
#  'lag_12',
#  'lag_12',
#  'lag_7',
#  'lag_17',
#  'lag_17',
#  'lag_9',
#  'lag_17',
#  'lag_7',
#  'lag_7',
#  'lag_17',
#  'lag_12',
#  'lag_9',
#  'lag_9',
#  'lag_12',
#  'lag_11',
#  'lag_11',
#  'lag_9',
#  'lag_19',
#  'lag_21',
#  'lag_18',
#  'lag_8',
#  'lag_4',
#  'lag_4',
#  'lag_8',
#  'lag_8',
#  'lag_8',
#  'lag_18',
#  'lag_15',
#  'lag_7',
#  'lag_7',
#  'lag_15',
#  'lag_21',
#  'lag_21',
#  'lag_21',
#  'lag_23',
#  'lag_12',
#  'lag_9',
#  'lag_9',
#  'lag_12',
#  'lag_16',
#  'lag_16',
#  'lag_23',
#  'lag_16',
#  'lag_4',
#  'lag_4',
#  'lag_16',
#  'lag_19',
#  'lag_19',
#  'lag_19',
#  'lag_4',
#  'lag_9',
#  'lag_1',
#  'lag_17',
#  'lag_17',
#  'lag_1',
#  'lag_9',
#  'lag_20',
#  'lag_20',
#  'lag_8',
#  'lag_8',
#  'lag_4',
#  'lag_5',
#  'lag_3',
#  'lag_13',
#  'lag_13',
#  'lag_3',
#  'lag_5',
#  'lag_4',
#  'lag_14',
#  'lag_14',
#  'lag_4',
#  'lag_3',
#  'lag_3',
#  'lag_12',
#  'lag_10',
#  'lag_14',
#  'lag_15',
#  'lag_15',
#  'lag_14',
#  'lag_10',
#  'lag_2',
#  'lag_21',
#  'lag_10',
#  'lag_20',
#  'lag_11',
#  'lag_11',
#  'lag_22',
#  'lag_22',
#  'lag_20',
#  'lag_22',
#  'lag_18',
#  'lag_18',
#  'lag_22',
#  'lag_12',
#  'lag_12',
#  'lag_10',
#  'lag_12',
#  'lag_19',
#  'lag_18',
#  'lag_18',
#  'lag_19',
#  'lag_19',
#  'lag_19',
#  'lag_12',
#  'lag_21',
#  'lag_12',
#  'lag_8',
#  'lag_8',
#  'lag_10',
#  'lag_10',
#  'lag_12',
#  'lag_8',
#  'lag_3',
#  'lag_3',
#  'lag_8',
#  'lag_15',
#  'lag_15',
#  'lag_2',
#  'lag_11',
#  'lag_24',
#  'lag_24',
#  'lag_19',
#  'lag_18',
#  'lag_2',
#  'lag_2',
#  'lag_18',
#  'lag_17',
#  'lag_17',
#  'lag_19',
#  'lag_7',
#  'lag_21',
#  'lag_21',
#  'lag_7',
#  'lag_11',
#  'lag_19',
#  'lag_21',
#  'lag_3',
#  'lag_19',
#  'lag_19',
#  'lag_3',
#  'lag_21',
#  'lag_4',
#  'lag_4',
#  'lag_23',
#  'lag_23',
#  'lag_19',
#  'lag_3',
#  'lag_18',
#  'lag_22',
#  'lag_15',
#  'lag_19',
#  'lag_23',
#  'lag_23',
#  'lag_19',
#  'lag_10',
#  'lag_10',
#  'lag_15',
#  'lag_18',
#  'lag_12',
#  'lag_12',
#  'lag_18',
#  'lag_22',
#  'lag_14',
#  'lag_18',
#  'lag_18',
#  'lag_3',
#  'lag_3',
#  'lag_14',
#  'lag_3',
#  'lag_3',
#  'lag_18',
#  'lag_15',
#  'lag_11',
#  'lag_14',
#  'lag_14',
#  'lag_23',
#  'lag_23',
#  'lag_11',
#  'lag_21',
#  'lag_2',
#  'lag_21',
#  'lag_21',
#  'lag_2',
#  'lag_9',
#  'lag_9',
#  'lag_9',
#  'lag_8',
#  'lag_8',
#  'lag_9',
#  'lag_21',
#  'lag_15',
#  'Demand',
#  'lag_24',
#  'lag_1',
#  'lag_8',
#  'lag_17',
#  'lag_15',
#  'lag_13',
#  'lag_13',
#  'lag_15',
#  'lag_17',
#  'lag_8',
#  'lag_12',
#  'lag_1',
#  'lag_5',
#  'lag_7',
#  'lag_7',
#  'lag_12',
#  'lag_21',
#  'lag_21',
#  'lag_12',
#  'lag_5',
#  'lag_11',
#  'lag_1',
#  'lag_18',
#  'lag_18',
#  'lag_1',
#  'lag_11',
#  'lag_11',
#  'lag_11',
#  'lag_14',
#  'lag_14',
#  'lag_14',
#  'lag_14',
#  'lag_24',
#  'lag_24',
#  'lag_1',
#  'lag_23',
#  'lag_23',
#  'lag_5',
#  'lag_20',
#  'lag_20',
#  'lag_5',
#  'lag_11',
#  'lag_11',
#  'lag_23',
#  'lag_1',
#  'lag_1',
#  'lag_1',
#  'lag_1',
#  'lag_23',
#  'lag_23',
#  'lag_23',
#  'lag_1',
#  'lag_22',
#  'lag_22',
#  'lag_18',
#  'lag_18',
#  'lag_1',
#  'lag_12',
#  'lag_1',
#  'lag_7',
#  'lag_7',
#  'lag_7',
#  'lag_7',
#  'lag_1',
#  'lag_4',
#  'lag_8',
#  'lag_8',
#  'lag_4',
#  'lag_1',
#  'lag_11',
#  'lag_23',
#  'lag_23',
#  'lag_11',
#  'lag_1',
#  'lag_4',
#  'lag_1',
#  'lag_7',
#  'lag_2',
#  'lag_2',
#  'lag_7',
#  'lag_8',
#  'lag_8',
#  'lag_1',
#  'lag_3',
#  'lag_5',
#  'lag_5',
#  'lag_3',
#  'lag_19',
#  'lag_19',
#  'lag_4',
#  'lag_21',
#  'lag_1',
#  'lag_6',
#  'lag_6',
#  'lag_1',
#  'lag_11',
#  'lag_11',
#  'lag_21',
#  'lag_1',
#  'lag_3',
#  'lag_22',
#  'lag_5',
#  'lag_3',
#  'lag_3',
#  'lag_5',
#  'lag_22',
#  'lag_10',
#  'lag_24',
#  'lag_24',
#  'lag_11',
#  'lag_19',
#  'lag_19',
#  'lag_11',
#  'lag_10',
#  'lag_19',
#  'lag_19',
#  'lag_3',
#  'lag_24',
#  'lag_1',
#  'lag_9',
#  'lag_1',
#  'lag_8',
#  'lag_8',
#  'lag_16',
#  'lag_16',
#  'lag_1',
#  'lag_3',
#  'lag_24',
#  'lag_24',
#  'lag_3',
#  'lag_9',
#  'lag_23',
#  'lag_5',
#  'lag_8',
#  'lag_8',
#  'lag_5',
#  'lag_22',
#  'lag_22',
#  'lag_23',
#  'lag_23',
#  'lag_15',
#  'lag_15',
#  'lag_23',
#  'lag_1',
#  'lag_5',
#  'lag_1',
#  'lag_2',
#  'lag_9',
#  'lag_9',
#  'lag_2',
#  'lag_20',
#  'lag_20',
#  'lag_1',
#  'lag_22',
#  'lag_22',
#  'lag_5',
#  'lag_4',
#  'lag_4',
#  'lag_24',
#  'lag_1',
#  'lag_13',
#  'lag_1',
#  'lag_23',
#  'lag_3',
#  'lag_3',
#  'lag_23',
#  'lag_1',
#  'lag_1',
#  'lag_1',
#  'lag_5',
#  'lag_18',
#  'lag_18',
#  'lag_5',
#  'lag_3',
#  'lag_3',
#  'lag_13',
#  'lag_21',
#  'lag_6',
#  'lag_6',
#  'lag_21',
#  'lag_1',
#  'lag_12',
#  'lag_12',
#  'lag_1',
#  'lag_1',
#  'lag_1',
#  'lag_24',
#  'lag_9',
#  'lag_12',
#  'lag_12',
#  'lag_9',
#  'lag_23',
#  'lag_23',
#  'lag_24',
#  'lag_3',
#  'lag_3',
#  'lag_1',
#  'lag_1',
#  'lag_1',
#  'lag_8',
#  'lag_11',
#  'lag_11',
#  'lag_8',
#  'lag_24',
#  'lag_24',
#  'lag_1',
#  'lag_1',
#  'lag_11',
#  'lag_11',
#  'lag_5',
#  'lag_19',
#  'lag_19',
#  'lag_5',
#  'lag_1',
#  'lag_17',
#  'lag_16',
#  'lag_18',
#  'lag_18',
#  'lag_16',
#  'lag_19',
#  'lag_19',
#  'lag_17',
#  'lag_1',
#  'lag_15',
#  'lag_1',
#  'lag_24',
#  'lag_14',
#  'lag_24',
#  'lag_24',
#  'lag_14',
#  'lag_6',
#  'lag_9',
#  'lag_9',
#  'lag_6',
#  'lag_21',
#  'lag_21',
#  'lag_24',
#  'lag_19',
#  'lag_22',
#  'lag_9',
#  'lag_9',
#  'lag_22',
#  'lag_19',
#  'lag_19',
#  'lag_19',
#  'lag_23',
#  'lag_23',
#  'lag_23',
#  'lag_23',
#  'lag_14',
#  'lag_14',
#  'lag_1',
#  'lag_10',
#  'lag_20',
#  'lag_20',
#  'lag_10',
#  'lag_19',
#  'lag_19',
#  'lag_4',
#  'lag_17',
#  'lag_17',
#  'lag_4',
#  'lag_15',
#  'lag_4',
#  'lag_23',
#  'lag_13',
#  'lag_23',
#  'lag_6',
#  'lag_6',
#  'lag_23',
#  'lag_24',
#  'lag_24',
#  'lag_13',
#  'lag_20',
#  'lag_15',
#  'lag_15',
#  'lag_20',
#  'lag_21',
#  'lag_21',
#  'lag_23',
#  'lag_11',
#  'lag_24',
#  'lag_5',
#  'lag_5',
#  'lag_24',
#  'lag_8',
#  'lag_8',
#  'lag_11',
#  'lag_10',
#  'lag_14',
#  'lag_14',
#  'lag_10',
#  'lag_4',
#  'lag_7',
#  'lag_6',
#  'lag_6',
#  'lag_7',
#  'lag_4',
#  'lag_6',
#  'lag_21',
#  'lag_21',
#  'lag_6',
#  'lag_23',
#  'lag_23',
#  'lag_4',
#  'lag_24',
#  'lag_1',
#  'lag_7',
#  'lag_1',
#  'lag_1',
#  'lag_1',
#  'lag_1',
#  'lag_22',
#  'lag_22',
#  'lag_18',
#  'lag_18',
#  'lag_1',
#  'lag_20',
#  'lag_24',
#  'lag_20',
#  'lag_20',
#  'lag_24',
#  'lag_20',
#  'lag_9',
#  'lag_6',
#  'lag_6',
#  'lag_9',
#  'lag_1',
#  'lag_8',
#  'lag_12',
#  'lag_14',
#  'lag_14',
#  'lag_12',
#  'lag_14',
#  'lag_6',
#  'lag_6',
#  'lag_14',
#  'lag_21',
#  'lag_21',
#  'lag_8',
#  'lag_7',
#  'lag_15',
#  'lag_9',
#  'lag_9',
#  'lag_15',
#  'lag_22',
#  'lag_22',
#  'lag_7',
#  'lag_14',
#  'lag_8',
#  'lag_8',
#  'lag_14',
#  'lag_7',
#  'lag_8',
#  'lag_12',
#  'lag_18',
#  'lag_13',
#  'lag_13',
#  'lag_18',
#  'lag_8',
#  'lag_18',
#  'lag_18',
#  'lag_8',
#  'lag_15',
#  'lag_15',
#  'lag_12',
#  'lag_1',
#  'lag_9',
#  'lag_23',
#  'lag_23',
#  'lag_9',
#  'lag_1',
#  'lag_8',
#  'lag_20',
#  'lag_20',
#  'lag_2',
#  'lag_2',
#  'lag_1',
#  'lag_2',
#  'lag_24',
#  'lag_14',
#  'lag_23',
#  'lag_10',
#  'lag_23',
#  'lag_23',
#  'lag_10',
#  'lag_6',
#  'lag_6',
#  'lag_23',
#  'lag_14',
#  'lag_23',
#  'lag_23',
#  'lag_11',
#  'lag_11',
#  'lag_13',
#  'lag_13',
#  'lag_24',
#  'lag_4',
#  'lag_23',
#  'lag_23',
#  'lag_4',
#  'lag_2',
#  'lag_13',
#  'lag_16',
#  'lag_10',
#  'lag_10',
#  'lag_9',
#  'lag_9',
#  'lag_16',
#  'lag_14',
#  'lag_14',
#  'lag_13',
#  'lag_7',
#  'lag_24',
#  'lag_20',
#  'lag_11',
#  'lag_11',
#  'lag_20',
#  'lag_1',
#  'lag_1',
#  'lag_24',
#  'lag_22',
#  'lag_23',
#  'lag_23',
#  'lag_22',
#  'lag_7',
#  'lag_1',
#  'lag_24',
#  'lag_15',
#  'lag_15',
#  'lag_24',
#  'lag_1',
#  'lag_1',
#  'lag_1',
#  'lag_7',
#  'lag_7',
#  'lag_6',
#  'lag_6',
#  'Temperature',
#  'lag_1',
#  'lag_23',
#  'lag_20',
#  'lag_5',
#  'lag_4',
#  'lag_1',
#  'lag_14',
#  'lag_19',
#  'lag_11',
#  'lag_11',
#  'lag_19',
#  'lag_21',
#  'lag_21',
#  'lag_14',
#  'lag_6',
#  'lag_15',
#  'lag_15',
#  'lag_6',
#  'lag_1',
#  'lag_22',
#  'lag_3',
#  'lag_3',
#  'lag_22',
#  'lag_11',
#  'lag_11',
#  'lag_12',
#  'lag_12',
#  'lag_4',
#  'lag_20',
#  'lag_1',
#  'lag_9',
#  'lag_23',
#  'lag_23',
#  'lag_9',
#  'lag_1',
#  'lag_5',
#  'lag_22',
#  'lag_22',
#  'lag_5',
#  'lag_3',
#  'lag_3',
#  'lag_20',
#  'lag_24',
#  'lag_1',
#  'lag_2',
#  'lag_2',
#  'lag_1',
#  'lag_24',
#  'lag_5',
#  'lag_1',
#  'lag_4',
#  'lag_18',
#  'lag_10',
#  'lag_10',
#  'lag_18',
#  'lag_4',
#  'lag_12',
#  'lag_12',
#  'lag_1',
#  'lag_21',
#  'lag_18',
#  'lag_12',
#  'lag_12',
#  'lag_18',
#  'lag_21',
#  'lag_11',
#  'lag_11',
#  'lag_20',
#  'lag_3',
#  'lag_3',
#  'lag_14',
#  'lag_20',
#  'lag_8',
#  'lag_8',
#  'lag_20',
#  'lag_11',
#  'lag_11',
#  'lag_8',
#  'lag_8',
#  'lag_14',
#  'lag_3',
#  'lag_21',
#  'lag_21',
#  'lag_20',
#  'lag_9',
#  'lag_18',
#  'lag_18',
#  'lag_9',
#  'lag_20',
#  'lag_3',
#  'lag_1',
#  'lag_20',
#  'lag_2',
#  'lag_19',
#  'lag_1',
#  'lag_1',
#  'lag_19',
#  'lag_2',
#  'lag_21',
#  'lag_21',
#  'lag_7',
#  'lag_7',
#  'lag_20',
#  'lag_1',
#  'lag_10',
#  'lag_14',
#  'lag_14',
#  'lag_10',
#  'lag_19',
#  'lag_19',
#  'lag_1',
#  'lag_19',
#  'lag_19',
#  'lag_20',
#  'lag_20',
#  'lag_1',
#  'lag_18',
#  'lag_22',
#  'lag_1',
#  'lag_1',
#  'lag_1',
#  'lag_1',
#  'lag_22',
#  'lag_1',
#  'lag_16',
#  'lag_16',
#  'lag_1',
#  'lag_3',
#  'lag_3',
#  'lag_18',
#  'lag_12',
#  'lag_1',
#  'lag_19',
#  'lag_19',
#  'lag_1',
#  'lag_13',
#  'lag_13',
#  'lag_12',
#  'lag_2',
#  'lag_14',
#  'lag_14',
#  'lag_2',
#  'lag_9',
#  'lag_9',
#  'lag_23',
#  'lag_10',
#  'lag_12',
#  'lag_14',
#  'lag_13',
#  'lag_9',
#  'lag_10',
#  'lag_10',
#  'lag_9',
#  'lag_1',
#  'lag_1',
#  'lag_15',
#  'lag_15',
#  'lag_13',
#  'lag_13',
#  'lag_24',
#  'lag_4',
#  'lag_4',
#  'lag_24',
#  'lag_22',
#  'lag_22',
#  'lag_13',
#  'lag_12',
#  'lag_7',
#  'lag_7',
#  'lag_12',
#  'lag_18',
#  'lag_18',
#  'lag_14',
#  'lag_11',
#  'lag_22',
#  'lag_23',
#  'lag_23',
#  'lag_16',
#  'lag_16',
#  'lag_22',
#  'lag_1',
#  'lag_3',
#  'lag_3',
#  'lag_1',
#  'lag_22',
#  'lag_22',
#  'lag_11',
#  'lag_8',
#  'lag_1',
#  'lag_1',
#  'lag_8',
#  'lag_12',
#  'lag_17',
#  'lag_17',
#  'lag_11',
#  'lag_22',
#  'lag_22',
#  'lag_11',
#  'lag_21',
#  'lag_21',
#  'lag_21',
#  'lag_21',
#  'lag_10',
#  'lag_11',
#  'lag_5',
#  'lag_8',
#  'lag_15',
#  'lag_15',
#  'lag_8',
#  'lag_13',
#  'lag_17',
#  'lag_17',
#  'lag_13',
#  'lag_7',
#  'lag_7',
#  'lag_5',
#  'lag_9',
#  'lag_6',
#  'lag_6',
#  'lag_4',
#  'lag_4',
#  'lag_9',
#  'lag_11',
#  'lag_1',
#  'lag_1',
#  'lag_18',
#  'lag_1',
#  'lag_16',
#  'lag_1',
#  'lag_12',
#  'lag_12',
#  'lag_1',
#  'lag_1',
#  'lag_22',
#  'lag_15',
#  'lag_15',
#  'lag_22',
#  'lag_9',
#  'lag_9',
#  'lag_1',
#  'lag_8',
#  'lag_8',
#  'lag_16',
#  'lag_1',
#  'lag_1',
#  'lag_21',
#  'lag_23',
#  'lag_23',
#  'lag_21',
#  'lag_24',
#  'lag_24',
#  'lag_1',
#  'lag_21',
#  'lag_5',
#  'lag_5',
#  'lag_21',
#  'lag_1',
#  'lag_11',
#  'lag_11',
#  'lag_1',
#  'lag_19',
#  'lag_18',
#  'lag_18',
#  'lag_21',
#  'lag_22',
#  'lag_22',
#  'lag_13',
#  'lag_13',
#  'lag_21',
#  'lag_19',
#  'lag_1',
#  'lag_20',
#  'lag_2',
#  'lag_2',
#  'lag_20',
#  'lag_1',
#  'lag_22',
#  'lag_1',
#  'lag_4',
#  'lag_4',
#  'lag_1',
#  'lag_22',
#  'lag_11',
#  'lag_11',
#  'lag_18',
#  'lag_18',
#  'lag_18',
#  'lag_10',
#  'lag_1',
#  'lag_9',
#  'lag_1',
#  'lag_13',
#  'lag_17',
#  'lag_17',
#  'lag_13',
#  'lag_2',
#  'lag_2',
#  'lag_1',
#  'lag_5',
#  'lag_22',
#  'lag_22',
#  'lag_5',
#  'lag_13',
#  'lag_13',
#  'lag_9',
#  'lag_22',
#  'lag_22',
#  'lag_21',
#  'lag_9',
#  'lag_9',
#  'lag_21',
#  'lag_23',
#  'lag_23',
#  'lag_1',
#  'lag_3',
#  'lag_6',
#  'lag_2',
#  'lag_2',
#  'lag_6',
#  'lag_22',
#  'lag_22',
#  'lag_3',
#  'lag_11',
#  'lag_4',
#  'lag_2',
#  'lag_2',
#  'lag_4',
#  'lag_5',
#  'lag_5',
#  'lag_11',
#  'lag_12',
#  'lag_7',
#  'lag_7',
#  'lag_12',
#  ...]

# %%
for feature in feature_names:
    

top_3_nodes
# Out:
#   Cell In [118], line 4
#     top_3_nodes
#     ^
# IndentationError: expected an indented block

# %%
top_3_nodes = pd.DataFrame(
                data = top_3_nodes,
                columns= ['first_node', 'second_node', 'third_node']
              )
top_3_nodes
# Out:
#    first_node  second_node   third_node
# 0       lag_1       Demand        lag_3
# 1       lag_1  Temperature       lag_24
# 2       lag_1       lag_24  Temperature
# 3       lag_1  Temperature       lag_24
# 4       lag_1       Demand       lag_19
# ..        ...          ...          ...
# 95      lag_1       Demand       lag_12
# 96      lag_1  Temperature       lag_24
# 97      lag_1  Temperature       lag_24
# 98      lag_1  Temperature       lag_24
# 99      lag_1       Demand       lag_18
#
# [100 rows x 3 columns]

# %%
for col in top_3_nodes.columns:
    print(col)
    print("---")
    print(top_3_nodes[col].value_counts())
# Out:
# first_node
# ---
# lag_1    100
# Name: first_node, dtype: int64
# second_node
# ---
# Demand         35
# Temperature    35
# lag_24         20
# lag_23         10
# Name: second_node, dtype: int64
# third_node
# ---
# lag_24         35
# Temperature    19
# Demand         11
# lag_18          9
# lag_17          7
# lag_1           4
# lag_12          4
# lag_20          2
# lag_4           2
# lag_14          2
# lag_3           1
# lag_19          1
# lag_8           1
# lag_9           1
# lag_6           1
# Name: third_node, dtype: int64

# %%
import re
r = [re.sub('\|--- ', '', node) for node in r.split('|   |')[:3]]
r = [re.sub('--- ', '', node) for node in r]
r = [re.sub('  +', '', node) for node in r]
r = [node.split(' ')[0]  for node in r]
print(r)
# Out:
# ['lag_1', 'Demand', 'lag_19']

# %%
r = [node.split(' ')[0]  for node in r]
# Out:
# ['lag_1',
#  'Demand',
#  'lag_19',
#  '',
#  'truncated',
#  'lag_19',
#  '',
#  'truncated',
#  'Demand',
#  'lag_24',
#  '',
#  'truncated',
#  'lag_24',
#  '',
#  'truncated',
#  'Demand',
#  'lag_3',
#  '',
#  'truncated',
#  'lag_3',
#  '',
#  'truncated',
#  'Demand',
#  'lag_1',
#  '',
#  'truncated',
#  'lag_1',
#  '',
#  'truncated']

# %%
[node.split(' ')[0]  for node in r]
# Out:
# ['|',
#  '-',
#  '-',
#  '-',
#  '',
#  'l',
#  'a',
#  'g',
#  '_',
#  '1',
#  '',
#  '<',
#  '=',
#  '',
#  '-',
#  '0',
#  '.',
#  '0',
#  '1',
#  '\n',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '-',
#  '-',
#  '-',
#  '',
#  'D',
#  'e',
#  'm',
#  'a',
#  'n',
#  'd',
#  '',
#  '<',
#  '=',
#  '',
#  '0',
#  '.',
#  '5',
#  '0',
#  '\n',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '-',
#  '-',
#  '-',
#  '',
#  'l',
#  'a',
#  'g',
#  '_',
#  '1',
#  '9',
#  '',
#  '<',
#  '=',
#  '',
#  '1',
#  '.',
#  '1',
#  '0',
#  '\n',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '-',
#  '-',
#  '-',
#  '',
#  't',
#  'r',
#  'u',
#  'n',
#  'c',
#  'a',
#  't',
#  'e',
#  'd',
#  '',
#  'b',
#  'r',
#  'a',
#  'n',
#  'c',
#  'h',
#  '',
#  'o',
#  'f',
#  '',
#  'd',
#  'e',
#  'p',
#  't',
#  'h',
#  '',
#  '2',
#  '6',
#  '\n',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '-',
#  '-',
#  '-',
#  '',
#  'l',
#  'a',
#  'g',
#  '_',
#  '1',
#  '9',
#  '',
#  '>',
#  '',
#  '',
#  '1',
#  '.',
#  '1',
#  '0',
#  '\n',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '-',
#  '-',
#  '-',
#  '',
#  't',
#  'r',
#  'u',
#  'n',
#  'c',
#  'a',
#  't',
#  'e',
#  'd',
#  '',
#  'b',
#  'r',
#  'a',
#  'n',
#  'c',
#  'h',
#  '',
#  'o',
#  'f',
#  '',
#  'd',
#  'e',
#  'p',
#  't',
#  'h',
#  '',
#  '1',
#  '2',
#  '\n',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '-',
#  '-',
#  '-',
#  '',
#  'D',
#  'e',
#  'm',
#  'a',
#  'n',
#  'd',
#  '',
#  '>',
#  '',
#  '',
#  '0',
#  '.',
#  '5',
#  '0',
#  '\n',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '-',
#  '-',
#  '-',
#  '',
#  'l',
#  'a',
#  'g',
#  '_',
#  '2',
#  '4',
#  '',
#  '<',
#  '=',
#  '',
#  '-',
#  '0',
#  '.',
#  '6',
#  '4',
#  '\n',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '-',
#  '-',
#  '-',
#  '',
#  't',
#  'r',
#  'u',
#  'n',
#  'c',
#  'a',
#  't',
#  'e',
#  'd',
#  '',
#  'b',
#  'r',
#  'a',
#  'n',
#  'c',
#  'h',
#  '',
#  'o',
#  'f',
#  '',
#  'd',
#  'e',
#  'p',
#  't',
#  'h',
#  '',
#  '1',
#  '6',
#  '\n',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '-',
#  '-',
#  '-',
#  '',
#  'l',
#  'a',
#  'g',
#  '_',
#  '2',
#  '4',
#  '',
#  '>',
#  '',
#  '',
#  '-',
#  '0',
#  '.',
#  '6',
#  '4',
#  '\n',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '-',
#  '-',
#  '-',
#  '',
#  't',
#  'r',
#  'u',
#  'n',
#  'c',
#  'a',
#  't',
#  'e',
#  'd',
#  '',
#  'b',
#  'r',
#  'a',
#  'n',
#  'c',
#  'h',
#  '',
#  'o',
#  'f',
#  '',
#  'd',
#  'e',
#  'p',
#  't',
#  'h',
#  '',
#  '1',
#  '7',
#  '\n',
#  '|',
#  '-',
#  '-',
#  '-',
#  '',
#  'l',
#  'a',
#  'g',
#  '_',
#  '1',
#  '',
#  '>',
#  '',
#  '',
#  '-',
#  '0',
#  '.',
#  '0',
#  '1',
#  '\n',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '-',
#  '-',
#  '-',
#  '',
#  'D',
#  'e',
#  'm',
#  'a',
#  'n',
#  'd',
#  '',
#  '<',
#  '=',
#  '',
#  '0',
#  '.',
#  '5',
#  '0',
#  '\n',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '-',
#  '-',
#  '-',
#  '',
#  'l',
#  'a',
#  'g',
#  '_',
#  '3',
#  '',
#  '<',
#  '=',
#  '',
#  '2',
#  '.',
#  '4',
#  '4',
#  '\n',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '-',
#  '-',
#  '-',
#  '',
#  't',
#  'r',
#  'u',
#  'n',
#  'c',
#  'a',
#  't',
#  'e',
#  'd',
#  '',
#  'b',
#  'r',
#  'a',
#  'n',
#  'c',
#  'h',
#  '',
#  'o',
#  'f',
#  '',
#  'd',
#  'e',
#  'p',
#  't',
#  'h',
#  '',
#  '2',
#  '5',
#  '\n',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '-',
#  '-',
#  '-',
#  '',
#  'l',
#  'a',
#  'g',
#  '_',
#  '3',
#  '',
#  '>',
#  '',
#  '',
#  '2',
#  '.',
#  '4',
#  '4',
#  '\n',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '-',
#  '-',
#  '-',
#  '',
#  't',
#  'r',
#  'u',
#  'n',
#  'c',
#  'a',
#  't',
#  'e',
#  'd',
#  '',
#  'b',
#  'r',
#  'a',
#  'n',
#  'c',
#  'h',
#  '',
#  'o',
#  'f',
#  '',
#  'd',
#  'e',
#  'p',
#  't',
#  'h',
#  '',
#  '4',
#  '\n',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '-',
#  '-',
#  '-',
#  '',
#  'D',
#  'e',
#  'm',
#  'a',
#  'n',
#  'd',
#  '',
#  '>',
#  '',
#  '',
#  '0',
#  '.',
#  '5',
#  '0',
#  '\n',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '-',
#  '-',
#  '-',
#  '',
#  'l',
#  'a',
#  'g',
#  '_',
#  '1',
#  '',
#  '<',
#  '=',
#  '',
#  '0',
#  '.',
#  '8',
#  '2',
#  '\n',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '-',
#  '-',
#  '-',
#  '',
#  't',
#  'r',
#  'u',
#  'n',
#  'c',
#  'a',
#  't',
#  'e',
#  'd',
#  '',
#  'b',
#  'r',
#  'a',
#  'n',
#  'c',
#  'h',
#  '',
#  'o',
#  'f',
#  '',
#  'd',
#  'e',
#  'p',
#  't',
#  'h',
#  '',
#  '1',
#  '5',
#  '\n',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '-',
#  '-',
#  '-',
#  '',
#  'l',
#  'a',
#  'g',
#  '_',
#  '1',
#  '',
#  '>',
#  '',
#  '',
#  '0',
#  '.',
#  '8',
#  '2',
#  '\n',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '',
#  '',
#  '',
#  '|',
#  '-',
#  '-',
#  '-',
#  '',
#  't',
#  'r',
#  'u',
#  'n',
#  'c',
#  'a',
#  't',
#  'e',
#  'd',
#  '',
#  'b',
#  'r',
#  'a',
#  'n',
#  'c',
#  'h',
#  '',
#  'o',
#  'f',
#  '',
#  'd',
#  'e',
#  'p',
#  't',
#  'h',
#  '',
#  '1',
#  '8',
#  '\n']

# %%
list(forecaster.create_train_X_y(data_modified[['Demand', 'Temperature']])[0].columns)
# Out:
# ['lag_1',
#  'lag_2',
#  'lag_3',
#  'lag_4',
#  'lag_5',
#  'lag_6',
#  'lag_7',
#  'lag_8',
#  'lag_9',
#  'lag_10',
#  'lag_11',
#  'lag_12',
#  'lag_13',
#  'lag_14',
#  'lag_15',
#  'lag_16',
#  'lag_17',
#  'lag_18',
#  'lag_19',
#  'lag_20',
#  'lag_21',
#  'lag_22',
#  'lag_23',
#  'lag_24',
#  'Demand',
#  'Temperature']

# %%
# %%html
# <style>
# .jupyter-wrapper .jp-CodeCell .jp-Cell-inputWrapper .jp-InputPrompt {display: none;}
# </style>
# Out:
# <style>
# .jupyter-wrapper .jp-CodeCell .jp-Cell-inputWrapper .jp-InputPrompt {display: none;}
# </style>
